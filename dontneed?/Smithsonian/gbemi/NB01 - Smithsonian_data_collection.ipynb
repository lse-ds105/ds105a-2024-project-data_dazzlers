# %%
import requests
import json

# %%
def get_met_objects(query, artist_or_culture=True):
    """
    Fetch object IDs from The Met API based on search parameters for artist/culture.

    Parameters:
    - query (str): Search term ('American') to collect objectIDs relating to America.
    - artist_or_culture (bool): Whether to search specifically for artist or culture.

    Returns:
    - dict: A dictionary containing the total count and a list of object IDs.
    """
    BASE_URL = "https://collectionapi.metmuseum.org/public/collection/v1/search"

    params = {
        "artistOrCulture": str(artist_or_culture).lower(), 
        "q": query
    }

    response = requests.get(BASE_URL, params=params)

    if response.status_code == 200:
        data = response.json()
        
        # Print the total number of objects found and the first few object IDs
        print(f"Total Objects Found: {data.get('total', 0)}")
        print(f"Sample Object IDs: {data.get('objectIDs', [])[:10]}")  # Display first 10 IDs for brevity
        
        return data
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None

search_results = get_met_objects("American")

print(search_results['objectIDs'])
# Out:
# Total Objects Found: 41182
# Sample Object IDs: [288149, 294011, 288322, 14494, 16298, 6635, 288301, 823321, 839285, 839286]
# [288149, 294011, 288322, 14494, 16298, 6635, 288301, 823321, 839285, 839286, 823315, 823322, 1691, 16299, 15907, 14326, 13370, 7985, 8369, 8357, 8411, 3532, 3533, 1980, 2737, 20732, 3531, 9313, 3838, 5762, 668740, 14434, 10464, 842089, 10360, 7586, 712140, 820841, 2046, 11130, 11396, 694642, 11981, 7938, 8685, 3697, 6636, 1076, 1662, 214, 744107, 702563, 4923, 288304, 3577, 11263, 11792, 10425, 10469, 10175, 10786, 10586, 10207, 13345, 13346, 13344, 8241, 35, 1084, 2211, 768547, 10080, 19037, 13471, 13211, 10154, 10481, 19261, 10127, 17139, 20144, 14930, 5505, 752047, 21126, 11050, 19405, 20895, 20894, 19067, 696866, 9724, 14282, 14336, 13052, 5223, 12052, 9317, 9997, 10501, 10827, 12649, 7604, 15387, 19303, 20129, 20621, 20498, 16805, 16677, 948, 7874, 2097, 19763, 8079, 21355, 765285, 14972, 7212, 15547, 1524, 11287, 668760, 9789, 7500, 9620, 8160, 9361, 9418, 14298, 14291, 14318, 14210, 14211, 19434, 20422, 19948, 17732, 21586, 21197, 7581, 7597, 7367, 7949, 560, 231, 239, 5509, 5575, 5563, 5427, 1078, 3985, 3877, 4579, 4715, 5638, 3480, 3173, 1999, 1981, 1530, 1442, 1427, 1423, 1839, 1860, 1667, 4289, 200, 1731, 3126, 3486, 12600, 12602, 15292, 13315, 20804, 11088, 11859, 11494, 11865, 5582, 11760, 19144, 12547, 11476, 1716, 7386, 1650, 4282, 4985, 5624, 3908, 11160, 7873, 10912, 10909, 20888, 11307, 10978, 20612, 202, 8073, 770850, 3497, 10746, 18354, 11707, 16307, 10465, 13070, 11227, 20615, 20893, 11040, 9480, 10913, 3152, 13124, 10813, 2390, 4286, 12702, 14833, 17073, 11764, 14488, 16719, 11145, 7876, 133, 7875, 9195, 14472, 14985, 3555, 13475, 17897, 9173, 707486, 726728, 667477, 20768, 458, 9819, 12004, 11619, 11133, 638280, 11080, 9594, 11951, 282, 14380, 21185, 11325, 11311, 10482, 10527, 10946, 12828, 11737, 11734, 16687, 3395, 10159, 10499, 14931, 10522, 24648, 24681, 4285, 4785, 503670, 5630, 5633, 12012, 503675, 4501, 6723, 8213, 8288, 9790, 15860, 16953, 802, 364, 1922, 2579, 2059, 4280, 3419, 4593, 4591, 668093, 834263, 761604, 813594, 10830, 11605, 13137, 16584, 19356, 13758, 12674, 12670, 820892, 830041, 698529, 1029, 9817, 10388, 11269, 712182, 13065, 11447, 10065, 11234, 10186, 10393, 11999, 10574, 10391, 10819, 10811, 13171, 20461, 13223, 12842, 13084, 13184, 16947, 20121, 813585, 700610, 755524, 275, 6782, 8088, 9821, 9580, 822464, 19346, 12140, 16255, 12477, 12127, 2408, 10554, 11790, 6778, 10997, 6779, 11820, 11116, 20517, 11122, 12019, 12822, 10049, 11157, 10497, 13134, 11417, 820215, 687677, 677910, 708024, 687670, 777786, 747045, 10557, 288300, 413556, 288147, 461366, 459516, 632, 9982, 11837, 1503, 3158, 1083, 10209, 7595, 1815, 716892, 639782, 21792, 21784, 21718, 21790, 7599, 7585, 261, 267, 246, 3879, 4538, 3159, 3417, 3643, 1894, 2473, 2251, 677213, 1997, 2038, 9601, 22769, 15125, 10804, 6186, 1430, 11136, 7475, 9384, 10011, 11602, 8247, 970, 15389, 1814, 1674, 18990, 2147, 332, 19018, 7508, 4590, 19202, 237, 1529, 13997, 7598, 781, 11941, 10793, 20415, 14309, 227, 751615, 757416, 823337, 823363, 823338, 823329, 823330, 823332, 3487, 715554, 715513, 715539, 718121, 726727, 726731, 726730, 653408, 665557, 657716, 680874, 682998, 684353, 675791, 680876, 702378, 698683, 698344, 10925, 12696, 9541, 8176, 822379, 843711, 19301, 916, 10747, 10126, 120, 6627, 7499, 2209, 35650, 24960, 10055, 11113, 12009, 13180, 10406, 14792, 11313, 20279, 20547, 11994, 701639, 6906, 856718, 24856, 14478, 839591, 12015, 11176, 487130, 490862, 487127, 461186, 232, 13772, 13773, 2468, 6871, 6861, 1175, 3134, 1996, 228, 911186, 854314, 751416, 757443, 835047, 746687, 24841, 14320, 14517, 14518, 14519, 823319, 823324, 823320, 823317, 839279, 839287, 839280, 288326, 288143, 849050, 2971, 14932, 15026, 4287, 11268, 11271, 11388, 11375, 11907, 10818, 11096, 10528, 10571, 10409, 10403, 10956, 12953, 13751, 13755, 14053, 12774, 12078, 12116, 182, 13115, 12075, 12087, 12120, 14521, 19745, 17066, 16577, 746422, 760942, 11055, 11667, 12138, 13215, 13498, 79269, 717542, 10821, 717589, 81141, 81108, 81678, 159364, 81130, 81453, 83 ...

# %%
import requests
import json

def generate_date_combinations(start_year=2014, end_year=2024):
    """
    Generate all combinations of start and end years between start_year and end_year.

    Parameters:
    - start_year (int): The starting year (default: 2014).
    - end_year (int): The ending year (default: 2024).

    Returns:
    - list of tuples: Each tuple contains a start year and an end year.
    """
    date_combinations = []
    for start in range(start_year, end_year + 1):
        for end in range(start, end_year + 1):  # end must be greater than or equal to start
            date_combinations.append((start, end))
    
    return date_combinations

combos = generate_date_combinations(2014,2024)
print(combos)
# Out:
# [(2014, 2014), (2014, 2015), (2014, 2016), (2014, 2017), (2014, 2018), (2014, 2019), (2014, 2020), (2014, 2021), (2014, 2022), (2014, 2023), (2014, 2024), (2015, 2015), (2015, 2016), (2015, 2017), (2015, 2018), (2015, 2019), (2015, 2020), (2015, 2021), (2015, 2022), (2015, 2023), (2015, 2024), (2016, 2016), (2016, 2017), (2016, 2018), (2016, 2019), (2016, 2020), (2016, 2021), (2016, 2022), (2016, 2023), (2016, 2024), (2017, 2017), (2017, 2018), (2017, 2019), (2017, 2020), (2017, 2021), (2017, 2022), (2017, 2023), (2017, 2024), (2018, 2018), (2018, 2019), (2018, 2020), (2018, 2021), (2018, 2022), (2018, 2023), (2018, 2024), (2019, 2019), (2019, 2020), (2019, 2021), (2019, 2022), (2019, 2023), (2019, 2024), (2020, 2020), (2020, 2021), (2020, 2022), (2020, 2023), (2020, 2024), (2021, 2021), (2021, 2022), (2021, 2023), (2021, 2024), (2022, 2022), (2022, 2023), (2022, 2024), (2023, 2023), (2023, 2024), (2024, 2024)]

# %%
SEARCH_BASE_URL = "https://collectionapi.metmuseum.org/public/collection/v1/search"

# The function to fetch object IDs
def get_object_ids(query=" ", date_begin=1920, date_end=2024):
    """
    Fetch object IDs from The Met Collection API based on query, date range, and optional filters.

    Parameters:
    - query (str): The search term (e.g., ""). Default is " " for a broad search.
    - date_begin (int): The starting year for the date range.
    - date_end (int): The ending year for the date range.

    Returns:
    - list: A list of object IDs that match the criteria.
    """
    params = {
        "q": query,  
        "dateBegin": date_begin,
        "dateEnd": date_end,
    }

    response = requests.get(SEARCH_BASE_URL, params=params)

    if response.status_code == 200:
        data = response.json()
        object_ids = data.get("objectIDs", [])

        if object_ids is None:
            return []
        
        print(f"Total Objects Found for {date_begin}-{date_end}: {data.get('total', 0)}")
        return object_ids
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return []

# Store all object IDs in a single list
date_ids = []

# Go through the combos list, calling the function for each pair
for combo in combos:
    date_begin, date_end = combo
    object_ids = get_object_ids(date_begin=date_begin, date_end=date_end)
    
    # Collect the object IDs into the list 
    date_ids.extend(object_ids)

print(date_ids)
# Out:
# Total Objects Found for 2014-2014: 136
# Total Objects Found for 2014-2015: 44
# Total Objects Found for 2014-2016: 28
# Total Objects Found for 2014-2017: 16
# Total Objects Found for 2014-2018: 13
# Total Objects Found for 2014-2019: 37
# Total Objects Found for 2014-2020: 15
# Total Objects Found for 2014-2021: 15
# Total Objects Found for 2014-2022: 7
# Total Objects Found for 2014-2023: 19
# Total Objects Found for 2014-2024: 8
# Total Objects Found for 2015-2015: 130
# Total Objects Found for 2015-2016: 52
# Total Objects Found for 2015-2017: 17
# Total Objects Found for 2015-2018: 9
# Total Objects Found for 2015-2019: 26
# Total Objects Found for 2015-2020: 7
# Total Objects Found for 2015-2021: 17
# Total Objects Found for 2015-2022: 5
# Total Objects Found for 2015-2023: 19
# Total Objects Found for 2015-2024: 12
# Total Objects Found for 2016-2016: 115
# Total Objects Found for 2016-2017: 31
# Total Objects Found for 2016-2018: 16
# Total Objects Found for 2016-2019: 19
# Total Objects Found for 2016-2020: 19
# Total Objects Found for 2016-2021: 20
# Total Objects Found for 2016-2022: 13
# Total Objects Found for 2016-2023: 10
# Total Objects Found for 2016-2024: 9
# Total Objects Found for 2017-2017: 98
# Total Objects Found for 2017-2018: 37
# Total Objects Found for 2017-2019: 11
# Total Objects Found for 2017-2020: 15
# Total Objects Found for 2017-2021: 11
# Total Objects Found for 2017-2022: 10
# Total Objects Found for 2017-2023: 14
# Total Objects Found for 2017-2024: 15
# Total Objects Found for 2018-2018: 76
# Total Objects Found for 2018-2019: 16
# Total Objects Found for 2018-2020: 13
# Total Objects Found for 2018-2021: 18
# Total Objects Found for 2018-2022: 15
# Total Objects Found for 2018-2023: 16
# Total Objects Found for 2018-2024: 9
# Total Objects Found for 2019-2019: 94
# Total Objects Found for 2019-2020: 24
# Total Objects Found for 2019-2021: 37
# Total Objects Found for 2019-2022: 15
# Total Objects Found for 2019-2023: 28
# Total Objects Found for 2019-2024: 8
# Total Objects Found for 2020-2020: 101
# Total Objects Found for 2020-2021: 52
# Total Objects Found for 2020-2022: 14
# Total Objects Found for 2020-2023: 26
# Total Objects Found for 2020-2024: 19
# Total Objects Found for 2021-2021: 93
# Total Objects Found for 2021-2022: 33
# Total Objects Found for 2021-2023: 27
# Total Objects Found for 2021-2024: 17
# Total Objects Found for 2022-2022: 68
# Total Objects Found for 2022-2023: 39
# Total Objects Found for 2022-2024: 18
# Total Objects Found for 2023-2023: 35
# Total Objects Found for 2023-2024: 29
# Total Objects Found for 2024-2024: 23
# [669451, 684796, 892141, 889901, 717498, 816793, 816792, 829999, 829996, 830002, 829997, 829998, 829994, 830000, 830003, 676599, 652765, 645188, 661747, 669098, 717494, 771206, 717493, 717500, 717490, 717499, 789700, 789701, 789702, 789703, 828711, 844702, 842055, 655979, 651079, 690537, 694690, 662551, 694155, 688246, 688249, 688247, 688250, 688248, 700117, 700120, 705748, 811181, 702058, 849042, 749353, 707006, 688254, 679214, 669962, 745914, 680697, 855067, 669367, 697572, 755756, 692361, 692359, 748811, 832352, 701017, 789696, 789697, 789698, 789699, 898380, 721941, 822572, 822575, 822573, 822574, 690751, 690753, 713006, 687413, 696840, 848800, 654839, 654843, 742557, 898464, 668412, 668408, 768449, 768438, 768439, 768448, 768450, 690156, 696314, 646439, 650250, 751587, 706008, 700746, 845220, 905595, 904132, 771137, 845789, 705757, 696802, 696804, 696805, 696803, 696806, 781566, 647798, 701498, 904137, 688118, 695275, 660347, 690185, 736642, 903965, 914834, 914837, 914838, 914839, 914840, 914836, 690444, 701014, 689732, 914831, 914832, 914830, 914835, 914833, 913093, 669451, 655979, 690537, 703106, 694155, 688246, 688249, 688247, 688250, 688248, 700117, 700120, 705748, 702058, 688254, 679214, 680697, 669367, 692361, 692359, 690751, 690753, 687413, 696840, 654839, 654843, 646439, 650250, 680138, 680137, 670153, 705757, 647798, 690185, 690444, 701014, 916665, 694690, 696804, 696805, 696803, 696802, 696806, 701498, 785431, 651079, 669962, 697572, 701017, 721941, 713006, 704351, 668412, 668408, 690156, 696314, 706008, 700751, 700964, 700746, 696802, 696804, 696805, 696803, 696806, 701498, 688118, 695275, 736642, 689732, 730769, 750855, 684796, 717498, 752049, 717494, 717493, 717500, 717490, 717499, 752071, 752069, 717497, 717495, 717496, 742557, 751587, 750855, 785431, 771206, 768449, 768438, 768439, 768448, 768450, 745914, 755756, 748811, 771137, 757277, 781566, 816793, 816792, 829999, 829996, 830002, 829997, 829998, 829994, 830000, 830003, 717498, 828711, 811181, 749353, 707006, 822572, 822575, 822573, 822574, 717494, 895906, 848288, 828727, 828728, 828724, 828729, 828726, 828717, 828725, 651079, 696802, 696804, 696805, 696803, 696806, 701498, 832503, 717498, 853971, 789696, 789697, 789698, 789699, 845220, 717494, 651079, 696802, 696804, 696805, 696803, 696806, 701498, 849042, 850927, 855067, 848800, 845789, 660347, 828727, 828728, 828724, 828729, 828726, 828717, 828725, 889270, 848288, 694690, 832352, 889272, 894459, 897517, 889270, 889021, 898464, 898380, 897867, 897517, 894459, 903965, 914834, 914837, 914838, 914839, 914840, 914836, 914831, 914832, 914830, 914835, 914833, 895906, 889021, 905595, 904132, 903508, 894459, 904137, 916665, 910332, 913093, 727404, 890008, 857111, 889365, 889317, 727970, 898024, 684260, 690446, 692322, 700408, 700409, 690067, 690424, 712634, 712635, 686545, 712633, 712632, 703197, 749861, 662819, 705760, 677668, 687966, 687965, 684775, 692455, 692454, 698067, 732551, 747141, 776714, 732615, 747327, 732549, 715147, 681174, 782085, 839576, 839550, 839553, 722515, 727557, 716210, 815800, 761395, 708520, 818005, 705956, 710452, 705456, 891049, 711635, 739224, 747860, 712209, 707003, 708538, 715078, 748810, 748814, 748815, 706915, 742920, 742911, 742922, 742935, 742936, 742921, 823227, 828123, 828124, 700194, 700198, 700201, 700195, 700196, 700199, 700203, 700205, 700200, 700202, 718448, 700797, 852864, 768404, 768441, 768451, 693825, 701471, 700752, 845792, 903027, 670834, 679039, 705284, 751939, 904141, 767666, 913111, 697473, 854073, 902340, 901845, 901848, 904129, 823225, 914842, 914841, 914846, 914847, 914844, 914845, 914848, 914843, 702483, 827350, 738442, 738441, 774360, 828720, 828723, 828721, 828718, 828719, 828722, 828706, 902210, 913092, 727970, 785431, 715147, 732551, 732615, 853787, 853789, 732549, 722515, 727557, 708520, 705956, 710452, 705456, 711635, 739224, 712209, 708538, 715078, 742920, 742911, 742922, 742935, 742936, 742921, 700198, 700201, 700195, 700196, 700194, 700199, 700203, ...

# %%
set_date= set(date_ids)
set_culture = set(search_results['objectIDs'])

# Find common elements using intersection
common_ids = list(set_date & set_culture)

print(common_ids)
# Out:
# [850946, 850947, 850948, 841220, 757262, 853009, 854546, 757268, 858135, 757271, 888344, 861227, 906284, 861229, 823853, 893486, 850988, 861231, 861232, 778803, 904758, 857657, 712766, 812111, 854614, 854615, 854623, 846944, 848996, 887908, 887913, 744554, 858220, 856706, 856710, 849041, 849042, 814739, 854685, 840865, 840866, 856231, 910503, 910504, 854703, 816835, 890564, 890565, 843477, 902869, 854753, 854754, 854755, 908530, 908531, 883957, 840444, 840966, 891156, 904478, 823604, 892213, 853824, 700748, 700750, 700751, 903516, 677213, 903517, 849764, 903049, 903053, 903054, 857498, 854428, 845220, 848294, 844716, 858035, 874932, 852916, 889270, 858036, 889272, 858037, 889278, 903630, 907224, 850908, 904160, 701921, 701922, 850923, 858095, 857592, 850937, 892922, 850939, 889855]

# %%
BASE_URL = "https://collectionapi.metmuseum.org/public/collection/v1/objects/"

def get_object_data(object_id):
    """
    Fetch detailed data for an object using its object ID.

    Parameters:
    - object_id (int): The object ID.

    Returns:
    - dict: A dictionary containing detailed data for the object.
    """
    url = f"{BASE_URL}{object_id}"
    response = requests.get(url)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching data for object ID {object_id}: {response.status_code}")
        return None

# Create an empty list to store all object data
all_data = []

# Get the object IDs from common_ids (filtered intersection of date-based IDs & search results)
object_ids = list(common_ids)  # Ensure it's a list

# Go through each object ID and fetch data
for object_id in object_ids:
    data = get_object_data(object_id)
    
    if data:
        all_data.append(data)
        print(f"Data for object ID {object_id} added to list.")

file_path = "../data/raw/art_data.json"
with open(file_path, 'w') as f:
    json.dump(all_data, f)

print(f"All object data saved to {file_path}")
# Out:
# Data for object ID 850946 added to list.
# Data for object ID 850947 added to list.
# Data for object ID 850948 added to list.
# Data for object ID 841220 added to list.
# Data for object ID 757262 added to list.
# Data for object ID 853009 added to list.
# Data for object ID 854546 added to list.
# Data for object ID 757268 added to list.
# Data for object ID 858135 added to list.
# Data for object ID 757271 added to list.
# Data for object ID 888344 added to list.
# Data for object ID 861227 added to list.
# Data for object ID 906284 added to list.
# Data for object ID 861229 added to list.
# Data for object ID 823853 added to list.
# Data for object ID 893486 added to list.
# Data for object ID 850988 added to list.
# Data for object ID 861231 added to list.
# Data for object ID 861232 added to list.
# Data for object ID 778803 added to list.
# Data for object ID 904758 added to list.
# Data for object ID 857657 added to list.
# Data for object ID 712766 added to list.
# Data for object ID 812111 added to list.
# Data for object ID 854614 added to list.
# Data for object ID 854615 added to list.
# Data for object ID 854623 added to list.
# Error fetching data for object ID 846944: 404
# Data for object ID 848996 added to list.
# Data for object ID 887908 added to list.
# Data for object ID 887913 added to list.
# Data for object ID 744554 added to list.
# Data for object ID 858220 added to list.
# Data for object ID 856706 added to list.
# Error fetching data for object ID 856710: 404
# Data for object ID 849041 added to list.
# Data for object ID 849042 added to list.
# Data for object ID 814739 added to list.
# Data for object ID 854685 added to list.
# Data for object ID 840865 added to list.
# Data for object ID 840866 added to list.
# Data for object ID 856231 added to list.
# Data for object ID 910503 added to list.
# Data for object ID 910504 added to list.
# Error fetching data for object ID 854703: 404
# Data for object ID 816835 added to list.
# Data for object ID 890564 added to list.
# Data for object ID 890565 added to list.
# Data for object ID 843477 added to list.
# Data for object ID 902869 added to list.
# Data for object ID 854753 added to list.
# Data for object ID 854754 added to list.
# Error fetching data for object ID 854755: 404
# Data for object ID 908530 added to list.
# Data for object ID 908531 added to list.
# Data for object ID 883957 added to list.
# Data for object ID 840444 added to list.
# Data for object ID 840966 added to list.
# Data for object ID 891156 added to list.
# Data for object ID 904478 added to list.
# Data for object ID 823604 added to list.
# Data for object ID 892213 added to list.
# Data for object ID 853824 added to list.
# Data for object ID 700748 added to list.
# Data for object ID 700750 added to list.
# Data for object ID 700751 added to list.
# Data for object ID 903516 added to list.
# Data for object ID 677213 added to list.
# Data for object ID 903517 added to list.
# Error fetching data for object ID 849764: 404
# Data for object ID 903049 added to list.
# Data for object ID 903053 added to list.
# Data for object ID 903054 added to list.
# Data for object ID 857498 added to list.
# Data for object ID 854428 added to list.
# Data for object ID 845220 added to list.
# Data for object ID 848294 added to list.
# Data for object ID 844716 added to list.
# Data for object ID 858035 added to list.
# Data for object ID 874932 added to list.
# Error fetching data for object ID 852916: 404
# Data for object ID 889270 added to list.
# Data for object ID 858036 added to list.
# Data for object ID 889272 added to list.
# Data for object ID 858037 added to list.
# Data for object ID 889278 added to list.
# Data for object ID 903630 added to list.
# Data for object ID 907224 added to list.
# Data for object ID 850908 added to list.
# Data for object ID 904160 added to list.
# Data for object ID 701921 added to list.
# Data for object ID 701922 added to list.
# Data for object ID 850923 added to list.
# Data for object ID 858095 added to list.
# Data for object ID 857592 added to list.
# Data for object ID 850937 added to list.
# Data for object ID 892922 added to list.
# Data for object ID 850939 added to list.
# Data for object ID 889855 added to list.
# All object data saved to ../data/raw/art_data.json
