# %%
import os
import json
import requests

import pandas as pd

# %%
filepath = '../data/raw/art_data.json'
art_df = pd.read_json(filepath)
art_df.head()
# Out:
#    objectID  isHighlight accessionNumber  accessionYear  isPublicDomain  \
# 0    850946        False   2023.588.1a–k           2023           False
# 1    850947        False   2023.588.2a–k           2023           False
# 2    850948         True     2022.503a–c           2022           False
# 3    841220        False   2020.267.4a–l           2020           False
# 4    757262        False   2018.134.1a–d           2018           False
#
#   primaryImage primaryImageSmall additionalImages  \
# 0                                              []
# 1                                              []
# 2                                              []
# 3                                              []
# 4                                              []
#
#                                         constituents         department  ...  \
# 0  [{'constituentID': 28401, 'role': 'Designer', ...  Costume Institute  ...
# ...
