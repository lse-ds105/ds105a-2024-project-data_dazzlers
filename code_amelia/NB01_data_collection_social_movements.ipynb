# %% [markdown]
# # How popular are different social movements over time?
#
# LSE DS105A - Data for Data Science (2024/25)
#
# **Date**: 18/11/24
#
# **Author**: Amelia Dunn
#
# **Objective**:🌟 Pull data files from GDELT API using Pytrends to get popularity of different social movements or events over time.

# %% [markdown]
# ## For google search using Pytrends instead - Cannot use this oops

# %% [markdown]
# - I tried investigating Reddit data, but you cannot access historical data
# - Then I tried investigating X (previously known as Twitter), but you could only access the historical data through paying.
# - We tried querying data from GDELT API, but we were only able to access data from 2014 onward, which we found to be too limiting. On top of this, it provides a seperate json file for each day from 2014 which is alot.
# - Tryed to get data from Open sanctions and open corporate, but found that this was an API you have to pay for
# - Now cycling back to GDELT and gathering data only from 2014 onwards.

# %% [markdown]
# ---

# %%
from pytrends.request import TrendReq
import pandas as pd
import json

def fetch_trends_data(keywords, geo='US', timeframe='2004-01-01 2023-12-31'):
    """
    Fetch Google Trends interest data for a list of keywords.
    """
    pytrends = TrendReq(hl='en-US', tz=360)
    trends_data = {}

    for keyword in keywords:
        try:
            pytrends.build_payload([keyword], timeframe=timeframe, geo=geo)
            interest_over_time = pytrends.interest_over_time()

            # Check if data exists
            if not interest_over_time.empty:
                # Convert Timestamp keys to string
                trends_data[keyword] = {date.strftime("%Y-%m-%d"): interest 
                                        for date, interest in interest_over_time[keyword].items()}
            else:
                print(f"No data available for '{keyword}'.")
        except Exception as e:
            print(f"An error occurred for '{keyword}': {e}")

    return trends_data

# Define a list of social movements - picked manually from a top 10 list of social movements researched online [find a webpage later]
movements = [
    "Black Lives Matter",
    "Me Too Movement",
    "Climate Strikes",
    "LGBTQ Rights",
    "Women's March",
    "Occupy Wall Street",
    "March for Our Lives",
    "Civil Rights Movement",
    "Environmental Activism",
    "Immigration Reform"
]

# Fetch data for the list of movements
raw_data = fetch_trends_data(movements, geo="US", timeframe="2004-01-01 2023-12-31")

# Save raw data to JSON
with open("../data_amelia/raw/social_movements_raw.json", "w") as json_file:
    json.dump(raw_data, json_file, indent=4)

print("Data has been saved to '../data_amelia/raw/social_movements_raw.json'")
# Out:
# Data has been saved to '../data_amelia/raw/social_movements_raw.json'

# %%
import json
import pandas as pd

def process_json_to_csv(json_file_path, csv_file_path):
    """
    Converts raw data from a JSON file to a CSV file.
    Args:
        json_file_path (str): Path to the input JSON file.
        csv_file_path (str): Path to the output CSV file.
    """
    try:
        # Load the JSON file
        with open(json_file_path, "r") as json_file:
            raw_data = json.load(json_file)
        
        # Process the data into a list of dictionaries
        processed_data = []
        for movement, data in raw_data.items():
            for date, interest in data.items():
                processed_data.append({"Movement": movement, "Date": date, "Interest": interest})
        
        # Create a DataFrame and save as CSV
        df = pd.DataFrame(processed_data)
        df.to_csv(csv_file_path, index=False)
        print(f"CSV file has been saved to {csv_file_path}.")
    except Exception as e:
        print(f"An error occurred while processing the JSON file: {e}")
        

# Example usage
json_file_path = "../data_amelia/raw/social_movements_raw.json"
csv_file_path = "../data_amelia/processed/social_movements.csv"

process_json_to_csv(json_file_path, csv_file_path)
# Out:
# CSV file has been saved to ../data_amelia/processed/social_movements.csv.

# %%
df
# Out:
#                 Movement        Date  Interest
# 0     Black Lives Matter  2004-01-01         0
# 1     Black Lives Matter  2004-02-01         0
# 2     Black Lives Matter  2004-03-01         0
# 3     Black Lives Matter  2004-04-01         0
# 4     Black Lives Matter  2004-05-01         0
# ...                  ...         ...       ...
# 2395  Immigration Reform  2023-08-01         2
# 2396  Immigration Reform  2023-09-01         3
# 2397  Immigration Reform  2023-10-01         3
# 2398  Immigration Reform  2023-11-01         3
# 2399  Immigration Reform  2023-12-01         3
#
# [2400 rows x 3 columns]

# %% [markdown]
# processing the data - move this to NB02 when have the time
#
# **TODO:** use SQLite to put the dataframe into a database and any other processing.

# %% [markdown]
# ---
#
# ## GDELT data:

# %% [markdown]
# Code for downloading all the zip files individually (if you want to use it)

# %%
import requests
import os
import time
from datetime import datetime, timedelta

def download_zip_file(url, output_dir, retries=3, delay=2):
    """
    Downloads a zip file from the given URL and stores it in the specified directory.
    
    Args:
        url (str): URL of the GDELT zip file.
        output_dir (str): Directory to save the zip files.
        retries (int): Number of retry attempts on failure.
        delay (int): Delay (in seconds) between retries.
        
    Returns:
        str: Path to the saved zip file, or None if the download failed.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    file_name = url.split("/")[-1]
    zip_path = os.path.join(output_dir, file_name)

    for attempt in range(retries):
        try:
            response = requests.get(url, timeout=30)
            if response.status_code == 404:
                print(f"File not found (404): {url}")
                return None
            elif response.status_code == 200:
                with open(zip_path, "wb") as zip_file:
                    zip_file.write(response.content)
                print(f"Downloaded zip file: {zip_path}")
                return zip_path
            else:
                print(f"Failed to download {url}. HTTP Status Code: {response.status_code}")
        except requests.exceptions.RequestException as e:
            print(f"Error downloading {url}: {e}")
        
        print(f"Retrying in {delay} seconds...")
        time.sleep(delay)

    print(f"Failed to download after {retries} attempts: {url}")
    return None


def fetch_gdelt_data_zip(start_date, end_date, output_dir="../data_amelia/raw", delay=2, retries=3):
    """
    Fetch GDELT data for a given date range (2014 onwards) and store as zip files.
    
    Args:
        start_date (str): Start date in 'YYYY-MM-DD' format.
        end_date (str): End date in 'YYYY-MM-DD' format.
        output_dir (str): Directory to store the downloaded zip files.
        delay (int): Delay (in seconds) between requests.
        retries (int): Number of retry attempts on failure.
    """
    start_date = datetime.strptime(start_date, "%Y-%m-%d")
    end_date = datetime.strptime(end_date, "%Y-%m-%d")
    current_date = start_date
    missing_files = []

    while current_date <= end_date:
        # For 2014 onwards, we use the daily file structure: YYYYMMDD.export.CSV.zip
        url = f"http://data.gdeltproject.org/events/{current_date.strftime('%Y%m%d')}.export.CSV.zip"

        # Download the zip file
        zip_path = download_zip_file(url, output_dir, retries, delay)
        if not zip_path:
            missing_files.append(url)

        # Increment date by one day
        current_date += timedelta(days=1)

        # Delay to avoid overloading the server
        print(f"Sleeping for {delay} seconds...")
        time.sleep(delay)

    # Log missing files
    if missing_files:
        missing_file_log = os.path.join(output_dir, "missing_files.log")
        with open(missing_file_log, "w") as log_file:
            for url in missing_files:
                log_file.write(f"{url}\n")
        print(f"Missing files logged to {missing_file_log}")


# Example usage: Fetch data from 2014 onwards
fetch_gdelt_data_zip(
    start_date="2014-01-01",  # Start from 2014
    end_date="2023-12-31",    # End on December 31st, 2023
    output_dir="../data_amelia/raw",    # Directory to save the zip files
    delay=2,                  # Delay in seconds between requests
    retries=3                 # Retry 3 times in case of failure
)
# Out:
# Downloaded zip file: ../data_amelia/raw/20140101.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140102.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140103.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140104.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140105.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140106.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140107.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140108.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140109.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140110.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140111.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140112.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140113.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140114.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140115.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140116.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140117.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140118.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140119.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140120.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140121.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140122.export.CSV.zip
# Sleeping for 2 seconds...
# File not found (404): http://data.gdeltproject.org/events/20140123.export.CSV.zip
# Sleeping for 2 seconds...
# File not found (404): http://data.gdeltproject.org/events/20140124.export.CSV.zip
# Sleeping for 2 seconds...
# File not found (404): http://data.gdeltproject.org/events/20140125.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140126.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140127.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140128.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140129.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140130.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140131.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140201.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140202.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140203.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140204.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140205.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140206.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140207.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140208.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140209.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140210.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140211.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140212.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140213.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140214.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140215.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140216.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140217.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140218.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140219.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140220.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140221.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140222.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140223.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140224.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140225.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140226.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140227.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140228.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140301.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140302.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140303.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140304.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140305.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140306.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140307.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140308.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140309.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140310.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140311.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140312.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140313.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140314.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140315.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140316.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140317.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140318.export.CSV.zip
# Sleeping for 2 seconds...
# File not found (404): http://data.gdeltproject.org/events/20140319.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140320.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140321.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140322.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140323.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140324.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140325.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140326.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140327.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140328.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140329.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140330.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140331.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140401.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140402.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140403.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140404.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140405.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140406.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140407.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140408.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140409.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140410.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140411.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140412.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140413.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140414.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140415.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140416.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140417.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140418.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140419.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140420.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140421.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140422.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140423.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140424.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140425.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140426.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140427.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140428.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140429.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140430.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140501.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140502.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140503.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140504.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140505.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140506.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140507.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140508.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140509.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140510.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140511.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140512.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140513.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140514.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140515.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140516.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140517.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140518.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140519.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140520.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140521.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140522.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140523.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140524.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140525.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140526.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140527.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140528.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140529.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140530.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140531.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140601.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140602.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140603.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140604.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140605.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140606.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140607.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140608.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140609.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140610.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140611.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140612.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140613.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140614.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140615.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140616.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140617.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140618.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140619.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140620.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140621.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140622.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140623.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140624.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140625.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140626.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140627.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140628.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140629.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140630.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140701.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140702.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140703.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140704.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140705.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140706.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140707.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140708.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140709.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140710.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140711.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140712.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140713.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140714.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140715.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140716.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140717.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140718.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140719.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140720.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140721.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140722.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140723.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140724.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140725.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140726.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140727.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140728.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140729.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140730.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140731.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140801.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140802.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140803.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140804.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140805.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140806.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140807.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140808.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140809.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140810.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140811.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140812.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140813.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140814.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140815.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140816.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140817.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140818.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140819.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140820.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140821.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140822.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140823.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140824.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140825.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140826.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140827.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140828.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140829.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140830.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140831.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140901.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140902.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140903.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140904.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140905.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140906.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140907.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140908.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140909.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140910.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140911.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140912.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140913.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140914.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140915.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140916.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140917.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140918.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140919.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140920.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140921.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140922.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140923.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140924.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140925.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140926.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140927.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140928.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140929.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20140930.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141001.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141002.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141003.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141004.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141005.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141006.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141007.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141008.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141009.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141010.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141011.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141012.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141013.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141014.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141015.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141016.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141017.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141018.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141019.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141020.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141021.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141022.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141023.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141024.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141025.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141026.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141027.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141028.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141029.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141030.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141031.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141101.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141102.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141103.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141104.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141105.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141106.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141107.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141108.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141109.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141110.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141111.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141112.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141113.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141114.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141115.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141116.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141117.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141118.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141119.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141120.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141121.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141122.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141123.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141124.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141125.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141126.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141127.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141128.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141129.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141130.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141201.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141202.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141203.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141204.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141205.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141206.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141207.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141208.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141209.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141210.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141211.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141212.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141213.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141214.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141215.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141216.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141217.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141218.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141219.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141220.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141221.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141222.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141223.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141224.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141225.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141226.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141227.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141228.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141229.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141230.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20141231.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150101.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150102.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150103.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150104.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150105.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150106.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150107.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150108.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150109.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150110.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150111.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150112.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150113.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150114.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150115.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150116.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150117.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150118.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150119.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150120.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150121.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150122.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150123.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150124.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150125.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150126.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150127.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150128.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150129.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150130.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150131.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150201.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150202.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150203.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150204.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150205.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150206.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150207.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150208.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150209.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150210.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150211.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150212.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150213.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150214.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150215.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150216.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150217.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150218.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150219.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150220.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150221.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150222.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150223.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150224.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150225.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150226.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150227.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150228.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150301.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150302.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150303.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150304.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150305.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150306.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150307.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150308.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150309.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150310.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150311.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150312.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150313.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150314.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150315.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150316.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150317.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150318.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150319.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150320.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150321.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150322.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150323.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150324.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150325.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150326.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150327.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150328.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150329.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150330.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150331.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150401.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150402.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150403.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150404.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150405.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150406.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150407.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150408.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150409.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150410.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150411.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150412.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150413.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150414.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150415.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150416.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150417.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150418.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150419.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150420.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150421.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150422.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150423.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150424.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150425.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150426.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150427.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150428.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150429.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150430.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150501.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150502.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150503.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150504.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150505.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150506.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150507.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150508.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150509.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150510.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150511.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150512.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150513.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150514.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150515.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150516.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150517.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150518.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150519.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150520.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150521.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150522.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150523.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150524.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150525.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150526.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150527.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150528.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150529.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150530.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150531.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150601.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150602.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150603.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150604.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150605.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150606.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150607.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150608.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150609.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150610.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150611.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150612.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150613.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150614.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150615.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150616.export.CSV.zip
# Sleeping for 2 seconds...
# ...
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150915.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150916.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150917.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150918.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150919.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150920.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150921.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150922.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150923.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150924.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150925.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150926.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150927.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150928.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150929.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20150930.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151001.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151002.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151003.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151004.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151005.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151006.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151007.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151008.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151009.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151010.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151011.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151012.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151013.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151014.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151015.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151016.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151017.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151018.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151019.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151020.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151021.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151022.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151023.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151024.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151025.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151026.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151027.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151028.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151029.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151030.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151031.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151101.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151102.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151103.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151104.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151105.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151106.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151107.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151108.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151109.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151110.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151111.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151112.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151113.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151114.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151115.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151116.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151117.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151118.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151119.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151120.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151121.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151122.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151123.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151124.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151125.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151126.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151127.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151128.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151129.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151130.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151201.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151202.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151203.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151204.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151205.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151206.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151207.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151208.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151209.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151210.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151211.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151212.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151213.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151214.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151215.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151216.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151217.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151218.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151219.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151220.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151221.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151222.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151223.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151224.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151225.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151226.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151227.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151228.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151229.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151230.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20151231.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160101.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160102.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160103.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160104.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160105.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160106.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160107.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160108.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160109.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160110.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160111.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160112.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160113.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160114.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160115.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160116.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160117.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160118.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160119.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160120.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160121.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160122.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160123.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160124.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160125.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160126.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160127.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160128.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160129.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160130.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160131.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160201.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160202.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160203.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160204.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160205.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160206.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160207.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160208.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160209.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160210.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160211.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160212.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160213.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160214.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160215.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160216.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160217.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160218.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160219.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160220.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160221.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160222.export.CSV.zip
# Sleeping for 2 seconds...
# Downloaded zip file: ../data_amelia/raw/20160223.export.CSV.zip
# Sleeping for 2 seconds...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 90
#      86         print(f"Missing files logged to {missing_file_log}")
#      89 # Example usage: Fetch data from 2014 onwards
# ---> 90 fetch_gdelt_data_zip(
#      91     start_date="2014-01-01",  # Start from 2014
#      92     end_date="2023-12-31",    # End on December 31st, 2023
#      93     output_dir="../data_amelia/raw",    # Directory to save the zip files
#      94     delay=2,                  # Delay in seconds between requests
#      95     retries=3                 # Retry 3 times in case of failure
#      96 )
#
# Cell In[1], line 69, in fetch_gdelt_data_zip(start_date, end_date, output_dir, delay, retries)
#      66 url = f"http://data.gdeltproject.org/events/{current_date.strftime('%Y%m%d')}.export.CSV.zip"
#      68 # Download the zip file
# ---> 69 zip_path = download_zip_file(url, output_dir, retries, delay)
#      70 if not zip_path:
#      71     missing_files.append(url)
#
# Cell In[1], line 33, in download_zip_file(url, output_dir, retries, delay)
#      31 elif response.status_code == 200:
#      32     with open(zip_path, "wb") as zip_file:
# ---> 33         zip_file.write(response.content)
#      34     print(f"Downloaded zip file: {zip_path}")
#      35     return zip_path
#
# OSError: [Errno 122] Disk quota exceeded

# %% [markdown]
# Processing the data so to not exceed the data limit

# %%
import requests
import zipfile
import io
import os
import pandas as pd
import time
from datetime import datetime

# List of column names as provided
GDELT_COLUMNS = [
    "GLOBALEVENTID", "SQLDATE", "MonthYear", "Year", "FractionDate", "Actor1Code", "Actor1Name", 
    "Actor1CountryCode", "Actor1KnownGroupCode", "Actor1EthnicCode", "Actor1Religion1Code", 
    "Actor1Religion2Code", "Actor1Type1Code", "Actor1Type2Code", "Actor1Type3Code", "Actor2Code", 
    "Actor2Name", "Actor2CountryCode", "Actor2KnownGroupCode", "Actor2EthnicCode", "Actor2Religion1Code", 
    "Actor2Religion2Code", "Actor2Type1Code", "Actor2Type2Code", "Actor2Type3Code", "IsRootEvent", 
    "EventCode", "EventBaseCode", "EventRootCode", "QuadClass", "GoldsteinScale", "NumMentions", 
    "NumSources", "NumArticles", "AvgTone", "Actor1Geo_Type", "Actor1Geo_FullName", "Actor1Geo_CountryCode", 
    "Actor1Geo_ADM1Code", "Actor1Geo_Lat", "Actor1Geo_Long", "Actor1Geo_FeatureID", "Actor2Geo_Type", 
    "Actor2Geo_FullName", "Actor2Geo_CountryCode", "Actor2Geo_ADM1Code", "Actor2Geo_Lat", "Actor2Geo_Long", 
    "Actor2Geo_FeatureID", "ActionGeo_Type", "ActionGeo_FullName", "ActionGeo_CountryCode", "ActionGeo_ADM1Code", 
    "ActionGeo_Lat", "ActionGeo_Long", "ActionGeo_FeatureID", "DATEADDED", "SOURCEURL"
]

def download_and_process_zip(url, output_dir, retries=3, delay=2):
    """
    Downloads and processes a zip file, adding column headers, filtering for US protest events, 
    and returns a filtered DataFrame.
    
    Args:
        url (str): URL of the GDELT zip file.
        output_dir (str): Directory to store the extracted files.
        retries (int): Number of retry attempts on failure.
        delay (int): Delay (in seconds) between retries.
        
    Returns:
        pd.DataFrame: Processed data, or None if the download failed.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    file_name = url.split("/")[-1]
    zip_path = os.path.join(output_dir, file_name)

    # Try to download the file with retries
    for attempt in range(retries):
        try:
            response = requests.get(url, timeout=30)
            if response.status_code == 404:
                print(f"File not found (404): {url}")
                return None
            elif response.status_code == 200:
                with zipfile.ZipFile(io.BytesIO(response.content)) as z:
                    # Extract the first file from the zip
                    for file in z.namelist():
                        with z.open(file) as csv_file:
                            # Read the CSV file into a DataFrame without headers
                            df = pd.read_csv(csv_file, sep='\t', header=None, low_memory=False)
                            
                            # Check the number of columns and adjust headers accordingly
                            num_columns = df.shape[1]
                            if num_columns == len(GDELT_COLUMNS):
                                df.columns = GDELT_COLUMNS
                            else:
                                print(f"Warning: Column mismatch. Expected {len(GDELT_COLUMNS)} columns, but found {num_columns}.")
                                # Optionally: Add handling for other column mismatches (e.g., truncating or adding dummy columns)
                            
                            # Filter for US protest events only (adjust column names as needed)
                            df_filtered = df[(df['Actor1Geo_CountryCode'] == 'US') & (df['EventCode'] == 140)]
                            return df_filtered
            else:
                print(f"Failed to download {url}. HTTP Status Code: {response.status_code}")
        except requests.exceptions.RequestException as e:
            print(f"Error downloading {url}: {e}")
        
        print(f"Retrying in {delay} seconds...")
        time.sleep(delay)

    print(f"Failed to download after {retries} attempts: {url}")
    return None


def process_year_data(start_year, end_year, output_dir="../data_amelia/processed"):
    """
    Processes data for the entire year, one zip file at a time, and saves the result as a single CSV.
    
    Args:
        start_year (int): Start year for the data.
        end_year (int): End year for the data.
        output_dir (str): Directory to store the extracted and processed data.
    """
    for year in range(start_year, end_year + 1):
        print(f"Processing data for year {year}...")
        year_data = pd.DataFrame()  # To store processed data for the year

        # Process each day in the year
        for month in range(1, 13):  # Loop over each month
            for day in range(1, 32):  # Loop over each day
                # Build the URL for the daily file (assuming the GDELT format is daily post 2013)
                url = f"http://data.gdeltproject.org/events/{year}{str(month).zfill(2)}{str(day).zfill(2)}.export.CSV.zip"
                
                # Download and process the zip file
                df_filtered = download_and_process_zip(url, output_dir)
                if df_filtered is not None:
                    # Concatenate the filtered data for the day into the year's dataframe
                    year_data = pd.concat([year_data, df_filtered], ignore_index=True)
                
                # Add a small delay between requests
                time.sleep(2)

        # Save the year's data to a CSV file
        if not year_data.empty:
            output_file = os.path.join(output_dir, f"{year}_protest_data.csv")
            year_data.to_csv(output_file, index=False)
            print(f"Year {year} data saved to {output_file}")
        else:
            print(f"No data found for year {year}.")

# Example usage: Process data from 2014 to 2023
process_year_data(start_year=2014, end_year=2023)
# Out:
# Processing data for year 2014...
# File not found (404): http://data.gdeltproject.org/events/20140123.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20140124.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20140125.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20140229.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20140230.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20140231.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20140319.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20140431.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20140631.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20140931.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20141131.export.CSV.zip
# Year 2014 data saved to gdelt_csv/2014_protest_data.csv
# Processing data for year 2015...
# File not found (404): http://data.gdeltproject.org/events/20150229.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20150230.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20150231.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20150431.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20150631.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20150931.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20151131.export.CSV.zip
# Year 2015 data saved to gdelt_csv/2015_protest_data.csv
# Processing data for year 2016...
# File not found (404): http://data.gdeltproject.org/events/20160230.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20160231.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20160431.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20160631.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20160931.export.CSV.zip
# /tmp/ipykernel_17809/805322857.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   year_data = pd.concat([year_data, df_filtered], ignore_index=True)
# File not found (404): http://data.gdeltproject.org/events/20161131.export.CSV.zip
# Year 2016 data saved to gdelt_csv/2016_protest_data.csv
# Processing data for year 2017...
# File not found (404): http://data.gdeltproject.org/events/20170229.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20170230.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20170231.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20170431.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20170631.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20170931.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20171131.export.CSV.zip
# Year 2017 data saved to gdelt_csv/2017_protest_data.csv
# Processing data for year 2018...
# File not found (404): http://data.gdeltproject.org/events/20180229.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20180230.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20180231.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20180431.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20180631.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20180931.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20181131.export.CSV.zip
# Year 2018 data saved to gdelt_csv/2018_protest_data.csv
# Processing data for year 2019...
# File not found (404): http://data.gdeltproject.org/events/20190229.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20190230.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20190231.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20190431.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20190631.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20190931.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20191131.export.CSV.zip
# Year 2019 data saved to gdelt_csv/2019_protest_data.csv
# Processing data for year 2020...
# /tmp/ipykernel_17809/805322857.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   year_data = pd.concat([year_data, df_filtered], ignore_index=True)
# File not found (404): http://data.gdeltproject.org/events/20200230.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20200231.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20200431.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20200631.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20200931.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20201131.export.CSV.zip
# Year 2020 data saved to gdelt_csv/2020_protest_data.csv
# Processing data for year 2021...
# File not found (404): http://data.gdeltproject.org/events/20210229.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20210230.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20210231.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20210431.export.CSV.zip
# File not found (404): http://data.gdeltproject.org/events/20210631.export.CSV.zip

# %% [markdown]
# **Note:** The function above will take at least 4 or 5 hours to get the data from. It also stopped running before it could collect data for the year 2023.
